# %% [markdown]
# <a href="https://colab.research.google.com/github/TheCuddleDoodle/singleton-image-format/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#singleton image format

# %%
# !python --version
# Out:
# Python 3.10.12

# %%
image = '...'
import io
import base64
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# Base64 to Bytes
bytes_img = base64.b64decode(image)

# Bytes to Pillow Image
pil_img = Image.open(io.BytesIO(bytes_img))

# Image to Numpy Array
numpy_img = np.array(pil_img)
plt.style.use('dark_background')
# Display Image
plt.imshow(numpy_img)
plt.show()

# %%
print(numpy_img.shape)
import math

image = '...'
import io
import base64
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# Base64 to Bytes
bytes_img = base64.b64decode(image)

# Bytes to Pillow Image
pil_img = Image.open(io.BytesIO(bytes_img))

single_ton = np.empty([numpy_img.shape[0],numpy_img.shape[1]])

for i in range(numpy_img.shape[0]):
   for j in range(numpy_img.shape[1]):
      single_ton[i][j] = 1 if numpy_img[i,j,3] > 0 else 0
print(single_ton.shape)
plt.style.use('dark_background')
# Display Image
plt.imshow(single_ton)
plt.show()
# Out:
# (60, 60, 4)
# (60, 60)
